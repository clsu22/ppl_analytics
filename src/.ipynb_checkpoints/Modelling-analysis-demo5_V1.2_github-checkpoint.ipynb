# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Modelling" data-toc-modified-id="Modelling-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Modelling</a></span><ul class="toc-item"><li><span><a href="#Feature-grouping" data-toc-modified-id="Feature-grouping-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Feature grouping</a></span></li><li><span><a href="#Feature-selection" data-toc-modified-id="Feature-selection-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Feature selection</a></span><ul class="toc-item"><li><span><a href="#LassoCV" data-toc-modified-id="LassoCV-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>LassoCV</a></span></li><li><span><a href="#RFECV" data-toc-modified-id="RFECV-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>RFECV</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Conclusion</a></span><ul class="toc-item"><li><span><a href="#Transform-testing-dataset-by-selector-of-LassoCV" data-toc-modified-id="Transform-testing-dataset-by-selector-of-LassoCV-1.2.3.1"><span class="toc-item-num">1.2.3.1&nbsp;&nbsp;</span>Transform testing dataset by selector of LassoCV</a></span></li></ul></li></ul></li><li><span><a href="#Hyperparameter-tuning" data-toc-modified-id="Hyperparameter-tuning-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Hyperparameter tuning</a></span><ul class="toc-item"><li><span><a href="#Use-LassoCV-selected-features" data-toc-modified-id="Use-LassoCV-selected-features-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Use LassoCV selected features</a></span><ul class="toc-item"><li><span><a href="#Result-without-any-hyperparameter-tuning" data-toc-modified-id="Result-without-any-hyperparameter-tuning-1.3.1.1"><span class="toc-item-num">1.3.1.1&nbsp;&nbsp;</span>Result without any hyperparameter tuning</a></span></li><li><span><a href="#Dummy" data-toc-modified-id="Dummy-1.3.1.2"><span class="toc-item-num">1.3.1.2&nbsp;&nbsp;</span>Dummy</a></span></li><li><span><a href="#Logistic-regression" data-toc-modified-id="Logistic-regression-1.3.1.3"><span class="toc-item-num">1.3.1.3&nbsp;&nbsp;</span>Logistic regression</a></span></li><li><span><a href="#SVM-RBF" data-toc-modified-id="SVM-RBF-1.3.1.4"><span class="toc-item-num">1.3.1.4&nbsp;&nbsp;</span>SVM RBF</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-1.3.1.5"><span class="toc-item-num">1.3.1.5&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#xgboost" data-toc-modified-id="xgboost-1.3.1.6"><span class="toc-item-num">1.3.1.6&nbsp;&nbsp;</span>xgboost</a></span></li><li><span><a href="#lgbm" data-toc-modified-id="lgbm-1.3.1.7"><span class="toc-item-num">1.3.1.7&nbsp;&nbsp;</span>lgbm</a></span></li><li><span><a href="#Multi-layer-perceptron" data-toc-modified-id="Multi-layer-perceptron-1.3.1.8"><span class="toc-item-num">1.3.1.8&nbsp;&nbsp;</span>Multi-layer perceptron</a></span></li></ul></li></ul></li><li><span><a href="#Classifier-selection" data-toc-modified-id="Classifier-selection-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Classifier selection</a></span><ul class="toc-item"><li><span><a href="#Metrics-comparison-(Cross-validation-and-test)" data-toc-modified-id="Metrics-comparison-(Cross-validation-and-test)-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Metrics comparison (Cross-validation and test)</a></span></li><li><span><a href="#Error-bar-comparison-(Cross-validation)" data-toc-modified-id="Error-bar-comparison-(Cross-validation)-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Error bar comparison (Cross-validation)</a></span></li></ul></li><li><span><a href="#Feature-experiment" data-toc-modified-id="Feature-experiment-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Feature experiment</a></span><ul class="toc-item"><li><span><a href="#Baseline-1:-Bag-of-words-with-Logistic-Regression" data-toc-modified-id="Baseline-1:-Bag-of-words-with-Logistic-Regression-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Baseline 1: Bag-of-words with Logistic Regression</a></span></li><li><span><a href="#Baseline-2:-Tf-idf-with-Logistic-regression" data-toc-modified-id="Baseline-2:-Tf-idf-with-Logistic-regression-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Baseline 2: Tf-idf with Logistic regression</a></span></li><li><span><a href="#Use-Logistic-regression-with-the-best-hyperparameter" data-toc-modified-id="Use-Logistic-regression-with-the-best-hyperparameter-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Use Logistic regression with the best hyperparameter</a></span></li><li><span><a href="#Use-SVM-with-the-best-hyperparameter" data-toc-modified-id="Use-SVM-with-the-best-hyperparameter-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>Use SVM with the best hyperparameter</a></span></li></ul></li><li><span><a href="#Result" data-toc-modified-id="Result-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Result</a></span><ul class="toc-item"><li><span><a href="#ROC,-Confusion-matrix-and-weights" data-toc-modified-id="ROC,-Confusion-matrix-and-weights-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>ROC, Confusion matrix and weights</a></span></li><li><span><a href="#Show-probabilities-for-each-observation-in-testing-dataset" data-toc-modified-id="Show-probabilities-for-each-observation-in-testing-dataset-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>Show probabilities for each observation in testing dataset</a></span></li><li><span><a href="#SHAP-explainer" data-toc-modified-id="SHAP-explainer-1.6.3"><span class="toc-item-num">1.6.3&nbsp;&nbsp;</span>SHAP explainer</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Modelling

# %% [markdown]
# Modelling_workflow.jpg![image.png](attachment:image.png)

# %% [markdown]
# ## Feature grouping

# %%
import pandas as pd
train = pd.read_csv("../data/manual_clean_training_dataset.csv")
train.rename(columns={"rehired_": "rehired_flag"}, inplace=True)
train.rehired_flag = train.rehired_flag.apply(lambda x: 1 if x=="Yes" else 0)

test = pd.read_csv("../data/manual_clean_testing_dataset.csv")
test.rename(columns={"rehired_": "rehired_flag"}, inplace=True)
test.rehired_flag = train.rehired_flag.apply(lambda x: 1 if x=="Yes" else 0)

print("- There are {0} observations in the training dataset\n- There are {1} observations in the testing dataset"
     .format(train.shape[0], test.shape[0]))
# Out:
# - There are 288 observations in the training dataset
# - There are 72 observations in the testing dataset

# %%
df_test = test.copy()
X_test = df_test.drop(columns=["hp_class"])
y_test = df_test["hp_class"]

# %%
# Build features dict 
feat_groups_dict = dict()
feat_groups_dict["academic_background"] = ['accounting_concentration', 'arts_concentration',
                                           'business_concentration', 'computer_systems_concentration',
                                           'engineering_concentration', 'finance_concentration',
                                           'general_concentration', 'human_resource_concentration',
                                           'interactive_arts_and_technology_concentration',
                                           'marketing_concentration', 'other_concentration', 
                                           'background_highest_degree', 'business_flag']
feat_groups_dict["educational_level"] = ['highest_degree', 'country_highest_degree', 
                                         'flag_hd_bachelor_plus', 'flag_hd_highschool']
feat_groups_dict["internal_glentel_profile"] = ['rehired_flag', 'referral_flag']
feat_groups_dict["job_counts"] = ['telco_electro_jobs', 'no_jobs', 'no_job_categorical', 'telco_electro_perc_group']
feat_groups_dict["job_tenure_general"] = ['job_hopper', 'average_tenure_per_job', 'shortest_tenure',
                                         'total_experience_months', 'longest_tenure']
feat_groups_dict["job_tenure_industry"] = ['sales_exp_months', 'customer_serv_exp_months',
                                           'leader_ship_exp_months']
feat_groups_dict["knowledge_and_skills"] = ['no_lang_spoken',
                                            'trilingual_flag', 'goal_record', 'sales_customer_base_exp',
                                            'volunteer_exp', 'problem_solver', 'sports_mention',
                                            'communication_skills', 'team_player', 'leadership_mention']
feat_groups_dict["readability"] = ['raw_dale_chall_readability', 'clean_Flesch-Kincaid_readability',
                                  'read_score_categorical']
feat_groups_dict["work_experience_industry"] =  ['competitor_experience', 
                                                 'Clothing_and_Footwear_industry_exp',
                                                'Consumer_electronics_industry_exp', 'Food_Service_industry_exp',
                                                'Food-Convenience-Pharmacy_industry_exp', 'Other_industry_exp',
                                                'Sport_Travel_Enterntain_Hotel_industry_exp',
                                                #'Telecommunications_industry_exp'
                                                ]
feat_groups_dict["work_experience_industry_recency"] = ['recency_type_telco_electro_exp', 'telco_electro_recency']
feat_groups_dict["work_experience_position"] = ['administrative_jobtitle',
                                               'assistant_manager_jobtitle', 'blue_collar_jobtitle',
                                                'cashier_jobtitle', 'cook_jobtitle',
                                               'customer_service_representative_jobtitle', 'driver_jobtitle',
                                               'education_jobtitle', 'financial_services_jobtitle',
                                               'fitness_sports_jobtitle', 'manager_jobtitle', 
                                               'other_jobtitle', 'sales_associate_jobtitle', 'technicians_jobtitle',
                                               'telemarketers_jobtitle']
feat_groups_df = pd.DataFrame.from_dict(feat_groups_dict, orient="index").T
feat_groups = list(feat_groups_dict.keys())
#feat_groups_df

# %%
# Split numerical and categorical features
features = []
for values in feat_groups_dict.values():
    features.append(values)
all_feat = sum(features, [])
numerical = sum(features, [])

categorical = ['background_highest_degree', 'highest_degree', 'country_highest_degree', 
               'recency_type_telco_electro_exp', 'telco_electro_perc_group', 'no_job_categorical',
               'read_score_categorical']
for x in categorical:
    numerical.remove(x) 
print("Features Summary:\n- total groups: {3}\n  - all features: {0}\n    - numerical: {1}\n    - categorical: {2}"
      .format(len(all_feat), len(numerical), len(categorical), len(feat_groups)))
# Out:
# Features Summary:
# - total groups: 11
#   - all features: 68
#     - numerical: 61
#     - categorical: 7

# %% [markdown]
# ## Feature selection
# Here we are trying two feature selection methods:
#     1. LassoCV
#     2. RFECV

# %%
# Load packages
import pandas as pd
import re
import datetime
import numpy as np
import matplotlib.pyplot as plt
from itertools import compress
import string 
import warnings
warnings.simplefilter('ignore')
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import recall_score, roc_auc_score, accuracy_score, plot_confusion_matrix, classification_report
#from imblearn.over_sampling import SMOTE
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn import tree 
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 

from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.preprocessing import normalize, scale, Normalizer, StandardScaler, OneHotEncoder

from sklearn.linear_model import LogisticRegression, LinearRegression

from sklearn.svm import SVC, SVR, LinearSVC
from sklearn.ensemble import RandomForestClassifier

from sklearn.tree import DecisionTreeRegressor
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline
from sklearn.preprocessing import FunctionTransformer

import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option("display.max_colwidth", 200)
from sklearn.feature_selection import RFECV

from sklearn.metrics import make_scorer, precision_score, f1_score, accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import recall_score, precision_score
from sklearn.metrics import roc_auc_score, roc_curve

from sklearn.linear_model import Lasso, Ridge
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectFromModel

from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_validate, GridSearchCV, RandomizedSearchCV

# %%
def show_weights(feat_names, weights, num):
    #feat_names #= X_train_sel_cols
    #weights #= lr.coef_.flatten()

    # Sort the coefficients in descending order 
    inds = np.argsort(weights)

    # pick the first 20 as most informative features for negative reviews  
    negative_words = [feat_names[index] for index in inds[:num]]

    # pick the last 20 features as most informative features for positive reviews  
    positive_words = [feat_names[index] for index in inds[-num:][::-1]]

    neg_words_weights = [(weights[index]) for index in inds[:num]]
    pos_words_weights = [(weights[index]) for index in inds[-num:][::-1]]

    df = pd.DataFrame({'Neg feats':negative_words, 'Neg weights':neg_words_weights, 
                       'Pos feats':positive_words, 'Pos weights':pos_words_weights})
    return df

# %%
def show_probs(employee_code, y_obs, y_pred, probs, dataset = "train"):
    '''
    Show probabilities 
    '''
    if dataset == "train":
        df1 = pd.DataFrame({"employee_code": employee_code, "y_obs_train": y_obs, "y_pred_train":y_pred}).reset_index(drop=True)
        df2 = pd.DataFrame(columns=["non-high performer", "high performer"],  data=probs)
        df_prob = pd.concat([df1, df2], axis =1)
        df_prob["False_positive"] = df_prob.apply(lambda row: 1 if row.y_obs_train == 0 and row.y_pred_train == 1 else 0, axis=1)
        df_prob["False_negative"] = df_prob.apply(lambda row: 1 if row.y_obs_train == 1 and row.y_pred_train == 0 else 0, axis=1)
    elif dataset == "test":
        df1 = pd.DataFrame({"employee_code": employee_code, "y_obs_test": y_obs, "y_pred_test":y_pred}).reset_index(drop=True)
        df2 = pd.DataFrame(columns=["non-high performer", "high performer"],  data=probs)
        df_prob = pd.concat([df1, df2], axis =1)
        df_prob["False_positive"] = df_prob.apply(lambda row: 1 if row.y_obs_test == 0 and row.y_pred_test ==1 else 0, axis=1)
        df_prob["False_negative"] = df_prob.apply(lambda row: 1 if row.y_obs_test == 1 and row.y_pred_test ==0 else 0, axis=1)
    return df_prob

# %% [markdown]
# ### LassoCV

# %%
# Load data 
df = train.copy()
numeric_features = numerical
categorical_features = categorical
X = df.drop(columns=["hp_class"])
y = df["hp_class"]

# %%
# Preprocess 
numeric_transformer = Pipeline(steps=[
                                      ('imputer', SimpleImputer(strategy='mean')),
                                      ('scaler', StandardScaler())
                                    ])


categorical_transformer = Pipeline(steps=[
                                          ('imputer', SimpleImputer(strategy='constant', 
                                                                    fill_value='missing')),
                                          ('onehot', OneHotEncoder(handle_unknown='ignore'))
                                         ])

preprocessor = ColumnTransformer(
                                 transformers=[
                                    ('num', numeric_transformer, numeric_features),
                                    ('cat', categorical_transformer, categorical_features)
                                ])

# %%
from sklearn.linear_model import LassoCV
#selector = SelectFromModel(estimator=LogisticRegression(solver ='liblinear',
#                                                        class_weight="balanced", 
#                                                        penalty="l1"))
selector = SelectFromModel(estimator=LassoCV())

# %%
clf_lassocv = Pipeline(steps=[('preprocessor', preprocessor),
                         ('selector',selector),
                     ])

# %%
# Make a dataframe containing L1 selected features 
X_trans = pd.DataFrame(preprocessor.fit_transform(X),
                           index=X.index,
                           columns=(numeric_features +
                                      list(preprocessor.named_transformers_['cat']['onehot']
                                           .get_feature_names(categorical_features))))

X_sel_lassocv = clf_lassocv.fit_transform(X, y)
X_sel_cols_lassocv = list(compress(X_trans.columns, selector.get_support()))
X_trans_sel_lassocv = pd.DataFrame(X_sel_lassocv, columns=X_sel_cols_lassocv)
print("- There are {0} features after preprocessing\n- L1 selected {1} features"
      .format(X_trans.shape[1], X_sel_lassocv.shape[1]))
# Out:
# - There are 99 features after preprocessing
# - L1 selected 9 features

# %%
feat_names = X_trans.columns
weights = selector.estimator_.coef_.flatten()
weights_lassocv_df = show_weights(feat_names, weights, 10)
weights_lassocv_df
# Out:
#                                               Neg feats  Neg weights  \
# 0                                    flag_hd_highschool    -0.017765
# 1                               fitness_sports_jobtitle    -0.004068
# 2                              accounting_concentration     0.000000
# 3                background_highest_degree_notspecified     0.000000
# 4                   background_highest_degree_marketing    -0.000000
# 5                         background_highest_degree_law    -0.000000
# 6  background_highest_degree_interactive art technology    -0.000000
# 7                     background_highest_degree_general    -0.000000
# 8                     background_highest_degree_finance     0.000000
# 9                 background_highest_degree_engineering    -0.000000
#
#                     Pos feats  Pos weights
# 0       competitor_experience     0.037604
# 1             trilingual_flag     0.031142
# 2     sales_customer_base_exp     0.020959
# ...

# %% [markdown]
# ### RFECV

# %%
clf_featr_sele = LogisticRegression(solver="liblinear", penalty="l1") 
rfecv = RFECV(estimator=clf_featr_sele, 
              cv=5, 
              scoring = 'f1'
             )
clf_rfecv = Pipeline(steps=[('preprocessor', preprocessor),
                          ('feature_sele',rfecv),
                     ])

# %%
clf_rfecv.fit(X, y)
X_sel_rfecv = X_trans.to_numpy()[:, rfecv.support_]
X_sel_cols_rfecv = list(compress(X_trans.columns, rfecv.support_))
X_trans_sel_rfecv = pd.DataFrame(X_sel_rfecv, columns=X_sel_cols_rfecv)
print("- There are {0} features after preprocessing\n- RFECV selected {1} features"
      .format(X_trans.shape[1], X_sel_rfecv.shape[1]))
# Out:
# - There are 99 features after preprocessing
# - RFECV selected 46 features

# %%
feat_names = X_trans.columns
weights = rfecv.estimator_.coef_.flatten()
weights_rfecv_df = show_weights(feat_names, weights, 10)
weights_rfecv_df
# Out:
#                                        Neg feats  Neg weights  \
# 0         Food-Convenience-Pharmacy_industry_exp    -1.206004
# 1                      Food_Service_industry_exp    -0.965928
# 2                          telco_electro_recency    -0.529939
# 3                                 no_lang_spoken    -0.499644
# 4                                  business_flag    -0.406340
# 5               clean_Flesch-Kincaid_readability    -0.389608
# 6  interactive_arts_and_technology_concentration    -0.286501
# 7                                  volunteer_exp    -0.267365
# 8                                 longest_tenure    -0.266804
# 9                            other_concentration    -0.256927
#
#                                     Pos feats  Pos weights
# 0                              sports_mention     0.762950
# 1  Sport_Travel_Enterntain_Hotel_industry_exp     0.656568
# 2                      average_tenure_per_job     0.650263
# ...

# %% [markdown]
# ### Conclusion
# - Seems RFE can't deal with multicollinearity very well. The selected features contradict our expectation and common knowledge. So we would choose LassoCV method and use LassoCV selected features for Hyperparameter tuning and classifier selection

# %% [markdown]
# #### Transform testing dataset by selector of LassoCV

# %%
X_test_sel_lassocv = clf_lassocv.transform(X_test)
X_test_trans_sel_lassocv = pd.DataFrame(X_test_sel_lassocv, columns=X_sel_cols_lassocv)
X_test_trans_sel_lassocv.shape
# Out:
# (72, 9)

# %% [markdown]
# ## Hyperparameter tuning
# Here we are going to tune hyperparameters of different ML classifiers using selected features

# %% [markdown]
# ### Use LassoCV selected features

# %%
def show_cv_score(model, X, y):
    score_result = {"accuracy":[], "recall":[], "precision":[], "roc_auc":[], "f1_score":[]}
    
    score_result["accuracy"].append(round(np.mean(cross_val_score(model, X, y, scoring="accuracy", cv=5)), 3))
    score_result["recall"].append(round(np.mean(cross_val_score(model, X, y, scoring="recall", cv=5)), 3))
    score_result["precision"].append(round(np.mean(cross_val_score(model, X, y, scoring="precision", cv=5)), 3))
    score_result["roc_auc"].append(round(np.mean(cross_val_score(model, X, y, scoring="roc_auc", cv=5)), 3))
    score_result["f1_score"].append(round(np.mean(cross_val_score(model, X, y, scoring="f1", cv=5)), 3))
    score_result = pd.DataFrame(score_result, index=["cross-validation"])
        
    return score_result

# %%
def format_cv_score(result_dict):
    score_result = {"accuracy":[], "recall":[], "precision":[], "roc_auc_score":[], "f1_score":[]}
    
    score_result["accuracy"].append(round(np.mean(result_dict['test_accuracy']), 3))
    score_result["recall"].append(round(np.mean(result_dict['test_recall']), 3))
    score_result["precision"].append(round(np.mean(result_dict['test_precision']), 3))
    score_result["roc_auc_score"].append(round(np.mean(result_dict['test_roc_auc']), 3))
    score_result["f1_score"].append(round(np.mean(result_dict['test_f1']), 3))
    
    score_result = pd.DataFrame(score_result, index=["cross-validation"])
    return score_result

# %%
def show_test_score(model, X_test, y_test):
    y_pred_test = model.predict(X_test)
    score_result = {"accuracy":[], "recall":[], "precision":[], "roc_auc_score":[], "f1_score":[]}
    score_result["accuracy"].append(round(accuracy_score(y_test, y_pred_test), 3))
    score_result["recall"].append(round(recall_score(y_test, y_pred_test), 3))
    score_result["precision"].append(round(precision_score(y_test, y_pred_test), 3))
    score_result["roc_auc_score"].append(round(roc_auc_score(y_test, model.predict_proba(X_test)[:,1]), 3))
    score_result["f1_score"].append(round(f1_score(y_test, y_pred_test), 3))
    
    score_result = pd.DataFrame(score_result, index=["test"])
    return score_result

# %%
from sklearn.dummy import DummyClassifier
models = {
          'dummy': DummyClassifier(strategy="most_frequent"),
          'logistic regression': LogisticRegression(),
          'RBF SVM' : SVC(), 
          'random forest' : RandomForestClassifier(), 
          'xgboost' : XGBClassifier(),
          'lgbm': LGBMClassifier(),
          'MLP': MLPClassifier()
         }

# %% [markdown]
# #### Result without any hyperparameter tuning

# %%
results_dict = {}
for model_name, model in models.items(): 
    clf = Pipeline(steps=[('preprocessor', preprocessor),
                         ('selector',selector),
                         ('classifier', model),
                         ])
    X_trans_sel = selector.fit_transform(preprocessor.fit_transform(X), y)
    print("Model:", model_name)
    print(show_cv_score(model, X_trans_sel, y))
    print("---")
# Out:
# Model: dummy
#                   accuracy  recall  precision  roc_auc  f1_score
# cross-validation     0.757     0.0        0.0      0.5       0.0
# ---
# Model: logistic regression
#                   accuracy  recall  precision  roc_auc  f1_score
# cross-validation     0.753     0.2      0.578    0.736     0.271
# ---
# Model: RBF SVM
#                   accuracy  recall  precision  roc_auc  f1_score
# cross-validation     0.785     0.2       0.67     0.66     0.306
# ---
# Model: random forest
#                   accuracy  recall  precision  roc_auc  f1_score
# cross-validation     0.712   0.257      0.371    0.615     0.309
# ---
# Model: xgboost
#                   accuracy  recall  precision  roc_auc  f1_score
# cross-validation     0.757   0.271      0.493    0.683     0.349
# ---
# Model: lgbm
#                   accuracy  recall  precision  roc_auc  f1_score
# cross-validation     0.719   0.157      0.331    0.672     0.211
# ---
# Model: MLP
# ...

# %% [markdown]
# > - Since there are multicollinearity issue, all classifiers perform not good.

# %% [markdown]
# #### Dummy

# %%
dummy_result = cross_validate(DummyClassifier(strategy="most_frequent"), X_trans_sel, y, cv=5,
                        scoring=('accuracy','f1','recall','precision','roc_auc'),
                        return_train_score=False)
dummy_result_df = format_cv_score(dummy_result)
dummy_result_df
# Out:
#                   accuracy  recall  precision  roc_auc_score  f1_score
# cross-validation     0.757     0.0        0.0            0.5       0.0

# %%
dummy = DummyClassifier(strategy="most_frequent")
dummy.fit(X_trans_sel, y)
# Out:
# DummyClassifier(constant=None, random_state=None, strategy='most_frequent')

# %% [markdown]
# #### Logistic regression

# %%
X_trans_sel = selector.fit_transform(preprocessor.fit_transform(X), y)
weights = np.linspace(0.1, 0.5, 9)
lr_param_grid = {"C": [0.1, 0.2, 0.3, 0.5, 1.0, 2.0, 3.0, 10, 100],
                'class_weight': [{0: x, 1: 1.0-x} for x in weights],
                }
lr_param_grid['class_weight'].append("balanced")
lr_gridsearchCV = GridSearchCV(estimator=LogisticRegression(),
                            param_grid= lr_param_grid,
                            cv=5,
                            scoring='f1',
                            n_jobs=2
                           ).fit(X_trans_sel, y)
print(lr_gridsearchCV.best_params_)
# Out:
# {'C': 0.1, 'class_weight': {0: 0.25, 1: 0.75}}

# %%
lr_result = cross_validate(lr_gridsearchCV, X_trans_sel, y, cv=5,
                        scoring=('accuracy','f1','recall','precision','roc_auc'),
                        return_train_score=False)
lr_result_df = format_cv_score(lr_result)
lr_result_df
# Out:
#                   accuracy  recall  precision  roc_auc_score  f1_score
# cross-validation      0.67     0.7      0.402          0.744     0.509

# %% [markdown]
# #### SVM RBF

# %%
weights = np.linspace(0.1, 0.5, 9)
svm_param_grid = {"C": [0.1, 0.2, 0.3, 0.5, 1.0, 2.0, 3.0, 10, 100],
                  'class_weight': [{0: x, 1: 1.0-x} for x in weights],
                  'gamma': [1, 0.1, 0.01, 0.001, 0.0001]
                }
svm_param_grid['class_weight'].append("balanced")
svm_gridsearchCV = GridSearchCV(estimator=SVC(probability=True),
                            param_grid= svm_param_grid,
                            cv=5,
                            scoring='f1',
                            n_jobs=2
                           ).fit(X_trans_sel, y)
print(svm_gridsearchCV.best_params_)
# Out:
# {'C': 10, 'class_weight': 'balanced', 'gamma': 0.001}

# %%
svm_result = cross_validate(svm_gridsearchCV, X_trans_sel, y, cv=5,
                        scoring=('accuracy','f1','recall','precision','roc_auc'),
                        return_train_score=False)
svm_result_df = format_cv_score(svm_result)
svm_result_df
# Out:
#                   accuracy  recall  precision  roc_auc_score  f1_score
# cross-validation     0.698   0.643      0.434          0.708      0.51

# %% [markdown]
# #### Random Forest

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 1000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
rf_param_grid = {'n_estimators': n_estimators,
                 'max_features': max_features,
                 'max_depth': max_depth,
                 'min_samples_split': min_samples_split,
                 'min_samples_leaf': min_samples_leaf,
                 'bootstrap': bootstrap,
                 'class_weight': [{0: x, 1: 1.0-x} for x in weights]
                }

rf_param_grid["class_weight"].append("balanced")
rf_randomsearchCV = RandomizedSearchCV(estimator=RandomForestClassifier(),
                            param_distributions= rf_param_grid,
                            n_iter = 100,
                            cv=5,
                            random_state=1234,
                            scoring='f1'
                           ).fit(X_trans_sel, y)
print(rf_randomsearchCV.best_params_)

# %%
rf_result = cross_validate(rf_randomsearchCV, X_trans_sel, y, cv=5,
                        scoring=('accuracy','f1','recall','precision','roc_auc'),
                        return_train_score=False)
rf_result_df = format_cv_score(rf_result)
rf_result_df
# Out:
#                   accuracy  recall  precision  roc_auc_score  f1_score
# cross-validation     0.705   0.586      0.425          0.665     0.486

# %% [markdown]
# #### xgboost

# %%
xgb_param_grid = {"learning_rate" : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ],
                      "max_depth": [ 3, 4, 5, 6, 8, 10, 12, 15],
                      "min_child_weight" : [ 1, 3, 5, 7 ],
                      "gamma": [1, 0.1, 0.01, 0.001, 0.0001],
                      "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ],
                      'class_weight': [{0: x, 1: 1.0-x} for x in weights]
                 }
xgb_randomsearchCV = RandomizedSearchCV(estimator=XGBClassifier(),
                            param_distributions= xgb_param_grid,
                            n_iter = 200,
                            cv=5,
                            random_state=1234,
                            scoring='f1'
                           ).fit(X_trans_sel, y)
print(xgb_randomsearchCV.best_params_)
# Out:
# {'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.15, 'gamma': 0.01, 'colsample_bytree': 0.7, 'class_weight': {0: 0.1, 1: 0.9}}

# %%
xgb_result = cross_validate(xgb_randomsearchCV, X_trans_sel, y, cv=5,
                        scoring=('accuracy','f1','recall','precision','roc_auc'),
                        return_train_score=False)
xgb_result_df = format_cv_score(xgb_result)
xgb_result_df
# Out:
#                   accuracy  recall  precision  roc_auc_score  f1_score
# cross-validation     0.726   0.229       0.39          0.642     0.286

# %% [markdown]
# #### lgbm

# %%
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
lgbm_param_grid ={'num_leaves': sp_randint(6, 50), 
                 'min_child_samples': sp_randint(100, 500), 
                 'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
                 'subsample': sp_uniform(loc=0.2, scale=0.8), 
                 'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
                 'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
                 'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100],
                 'class_weight': [{0: x, 1: 1.0-x} for x in weights]
                 }
lgbm_param_grid['class_weight'].append("balanced")
lgbm_randomsearchCV = RandomizedSearchCV(estimator=LGBMClassifier(),
                            param_distributions= lgbm_param_grid,
                            n_iter = 300,
                            cv=5,
                            random_state=1234,
                            scoring='f1'
                           ).fit(X_trans_sel, y)
print(lgbm_randomsearchCV.best_params_)
# Out:
# {'class_weight': 'balanced', 'colsample_bytree': 0.44522874498578596, 'min_child_samples': 103, 'min_child_weight': 0.01, 'num_leaves': 25, 'reg_alpha': 0.1, 'reg_lambda': 5, 'subsample': 0.5177620621809234}

# %%
lgbm_result = cross_validate(lgbm_randomsearchCV, X_trans_sel, y, cv=5,
                        scoring=('accuracy','f1','recall','precision','roc_auc'),
                        return_train_score=False)
lgbm_result_df = format_cv_score(lgbm_result)
lgbm_result_df
# Out:
#                   accuracy  recall  precision  roc_auc_score  f1_score
# cross-validation     0.243     1.0      0.243            0.5     0.391

# %% [markdown]
# #### Multi-layer perceptron

# %%
mlp_param_grid = {
    'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
}
mlp_gridsearchCV = GridSearchCV(estimator=MLPClassifier(),
                            param_grid= mlp_param_grid,
                            cv=5,
                            scoring='f1'
                           ).fit(X_trans_sel, y)
print(mlp_gridsearchCV.best_params_)
# Out:
# {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}

# %%
mlp_result = cross_validate(mlp_gridsearchCV, X_trans_sel, y, cv=5,
                        scoring=('accuracy','f1','recall','precision','roc_auc'),
                        return_train_score=False)
mlp_result_df = format_cv_score(mlp_result)
mlp_result_df
# Out:
#                   accuracy  recall  precision  roc_auc_score  f1_score
# cross-validation     0.774   0.257      0.575          0.716     0.346

# %% [markdown]
# ## Classifier selection

# %% [markdown]
# ### Metrics comparison (Cross-validation and test)

# %%
# Show cross-validation metrics 
model_name = pd.DataFrame({"model":['Dummy','Logistic Regression', "SVM", "Random Forest", "XGBoost", "LGBM", "Malti-layer Perceptron"]})
cv_result = (pd.concat([model_name, 
                       pd.concat([dummy_result_df, lr_result_df, svm_result_df, rf_result_df, xgb_result_df, lgbm_result_df, mlp_result_df], axis=0)
                       .reset_index()],axis=1)
             .drop(columns=["index"])).set_index("model")

arrays = [['cross-validation', 'cross-validation', 'cross-validation', 'cross-validation', 'cross-validation'],
         ['accuracy', 'recall', 'precision', 'roc_auc', 'f1']]
tuples = list(zip(*arrays))
index = pd.MultiIndex.from_tuples(tuples, names=['', ''])

cv_result.columns = index

# %%
# Show test metrics 
dummy_test_df = show_test_score(dummy, X_test_trans_sel_lassocv, y_test)
lr_test_df = show_test_score(lr_gridsearchCV, X_test_trans_sel_lassocv, y_test)
svm_test_df = show_test_score(svm_gridsearchCV, X_test_trans_sel_lassocv, y_test)
rf_test_df = show_test_score(rf_randomsearchCV, X_test_trans_sel_lassocv, y_test)
xgb_test_df = show_test_score(xgb_randomsearchCV, X_test_trans_sel_lassocv.to_numpy(), y_test)
lgbm_test_df = show_test_score(lgbm_randomsearchCV, X_test_trans_sel_lassocv, y_test)
mlp_test_df = show_test_score(mlp_gridsearchCV, X_test_trans_sel_lassocv, y_test)

test_result = (pd.concat([model_name, 
                       pd.concat([dummy_test_df, lr_test_df, svm_test_df, rf_test_df, xgb_test_df, lgbm_test_df, mlp_test_df], axis=0)
                       .reset_index()],axis=1)
             .drop(columns=["index"])).set_index("model")

test_arrays = [['test', 'test', 'test', 'test', 'test'],
         ['accuracy', 'recall', 'precision', 'roc_auc', 'f1']]
test_tuples = list(zip(*test_arrays))
test_index = pd.MultiIndex.from_tuples(test_tuples, names=['', ''])

test_result.columns = test_index

# %%
cv_test_result = pd.concat([cv_result, test_result], axis=1)
cv_test_result
# Out:
#                        cross-validation                                  \
#                                accuracy recall precision roc_auc     f1
# model
# Dummy                             0.757  0.000     0.000   0.500  0.000
# Logistic Regression               0.670  0.700     0.402   0.744  0.509
# SVM                               0.698  0.643     0.434   0.708  0.510
# Random Forest                     0.705  0.586     0.425   0.665  0.486
# XGBoost                           0.726  0.229     0.390   0.642  0.286
# LGBM                              0.243  1.000     0.243   0.500  0.391
# Malti-layer Perceptron            0.774  0.257     0.575   0.716  0.346
#
#                            test
#                        accuracy recall precision roc_auc     f1
# model
# Dummy                     0.694  0.000     0.000   0.500  0.000
# Logistic Regression       0.583  0.682     0.395   0.585  0.500
# SVM                       0.569  0.636     0.378   0.590  0.475
# ...

# %%
#show_test_score(svm_gridsearchCV.best_estimator_.fit(X_trans_sel, y), X_test_trans_sel_lassocv, y_test)

# %% [markdown]
# - From both cross-validation and test scores, SVM performs the best

# %% [markdown]
# ### Error bar comparison (Cross-validation)

# %%
def make_barplot(metric):
    """
    metric options: 'accuracy', 'f1', 'recall', 'precision', 'roc_auc'
    """
    dummy = dummy_result['test_'+metric]
    lr = lr_result['test_'+metric]
    svm = svm_result['test_'+metric]
    rf =rf_result['test_'+metric]
    xgb = xgb_result['test_'+metric]
    lgbm = lgbm_result['test_'+metric]
    mlp = mlp_result['test_'+metric]
    
    dummy_mean, dummy_std = np.mean(dummy), np.std(dummy)
    lr_mean, lr_std = np.mean(lr), np.std(lr)
    svm_mean, svm_std = np.mean(svm), np.std(svm)
    rf_mean, rf_std = np.mean(rf), np.std(rf)
    xgb_mean, xgb_std = np.mean(xgb), np.std(xgb)
    lgbm_mean, lgbm_std = np.mean(lgbm), np.std(lgbm)
    mlp_mean, mlp_std = np.mean(mlp), np.std(mlp)

    labels = ['Dummy','Logistic Regression', 'SVM', 'Random Forest', "XGBoost", "LGBM", "MLP"]
    x_pos = np.arange(len(labels))
    CTEs = [dummy_mean, lr_mean, svm_mean, rf_mean, xgb_mean, lgbm_mean, mlp_mean]
    error = [dummy_std, lr_std, svm_std, rf_std, xgb_std, lgbm_std, mlp_std]

    fig, ax = plt.subplots(figsize=(9, 6))
    ax.bar(x_pos, CTEs,
           yerr=error,
           align='center',
           alpha=0.5,
           ecolor='black',
           capsize=10)
    ax.set_ylabel(metric)
    ax.set_xticks(x_pos)
    ax.set_xticklabels(labels)
    ax.set_title(metric+' score of different ML classifiers (Cross-validation)')
    ax.yaxis.grid(True)
    
    # Save the figure and show
    plt.tight_layout()
    plt.savefig('bar_plot_with_error_bars.png')
    plt.show()

# %%
make_barplot("f1")

# %% [markdown]
# ## Feature experiment
# After comparison, we have two good classifiers as options: SVM and Logistic regression.
# We are intereted in the input of features. So here we are going to do feature experiment on groups of features by using Logistic regression and SVM to compare feature importance between groups of features. We are going to exclude one group of features one time and apply the classifiers with the best hyperparameter to see the scores.

# %% [markdown]
# ### Baseline 1: Bag-of-words with Logistic Regression

# %%
X_wc = train["clean_text"]
y_wc = train["hp_class"]

X_test_wc = test["clean_text"]
y_test_wc = test["hp_class"]

vec = CountVectorizer(max_features=5000, ngram_range=(2, 2))
X_counts = vec.fit_transform(X_wc) 
X_test_counts = vec.transform(X_test_wc)

wc_lr_gridsearchCV = GridSearchCV(estimator=LogisticRegression(),
                            param_grid= lr_param_grid,
                            cv=5,
                            scoring='f1',
                            n_jobs=2
                           ).fit(X_counts, y_wc)

print(wc_lr_gridsearchCV.best_params_)
# Out:
# {'C': 0.1, 'class_weight': {0: 0.1, 1: 0.9}}

# %%
wc_lr_result = cross_validate(wc_lr_gridsearchCV, X_counts, y_wc, cv=5,
                        scoring=('accuracy','f1','recall','precision','roc_auc'),
                        return_train_score=False)
wc_lr_result_df = format_cv_score(wc_lr_result)
wc_lr_result_df
# Out:
#                   accuracy  recall  precision  roc_auc_score  f1_score
# cross-validation      0.34   0.786      0.234          0.505     0.359

# %%
wc_lr_test_result = show_test_score(wc_lr_gridsearchCV, X_test_counts, y_test_wc)
wc_lr_test_result
# Out:
#       accuracy  recall  precision  roc_auc_score  f1_score
# test     0.319   0.818      0.286          0.509     0.424

# %% [markdown]
# ### Baseline 2: Tf-idf with Logistic regression

# %%
X_tfidf = train["clean_text"]
y_tfidf = train["hp_class"]

X_test_tfidf = test["clean_text"]
y_test_tfidf = test["hp_class"]

vec2 = TfidfVectorizer(max_features=5000, ngram_range=(2, 2))
X_tfidf = vec2.fit_transform(X_tfidf) 
X_test_tfidf = vec2.transform(X_test_tfidf)

tfidf_lr_gridsearchCV = GridSearchCV(estimator=LogisticRegression(),
                            param_grid= lr_param_grid,
                            cv=5,
                            scoring='f1',
                            n_jobs=2
                           ).fit(X_tfidf, y_tfidf)

print(tfidf_lr_gridsearchCV.best_params_)
# Out:
# {'C': 1.0, 'class_weight': {0: 0.2, 1: 0.8}}

# %%
tfidf_lr_result = cross_validate(tfidf_lr_gridsearchCV, X_tfidf, y_tfidf, cv=5,
                        scoring=('accuracy','f1','recall','precision','roc_auc'),
                        return_train_score=False)
tfidf_lr_result_df = format_cv_score(tfidf_lr_result)
tfidf_lr_result_df
# Out:
#                   accuracy  recall  precision  roc_auc_score  f1_score
# cross-validation     0.243   0.971      0.239           0.54     0.384

# %%
tfidf_lr_test_result = show_test_score(tfidf_lr_gridsearchCV, X_test_counts, y_test_wc)
tfidf_lr_test_result
# Out:
#       accuracy  recall  precision  roc_auc_score  f1_score
# test     0.528   0.591      0.342          0.563     0.433

# %% [markdown]
# ### Use Logistic regression with the best hyperparameter

# %%
# Experiment using Logistic regression 
from IPython.display import clear_output
feat_expr_result = dict()
feat_expr_test_result = dict()
for i in range(len(feat_groups)):
    clear_output(wait=True)
    cat_feat_cur = categorical.copy()
    num_feat_cur = numerical.copy()
    for j in range(len(feat_groups_dict[feat_groups[i]])):
        if feat_groups_dict[feat_groups[i]][j] in categorical:
            cat_feat_cur.remove(feat_groups_dict[feat_groups[i]][j])
        else:
            num_feat_cur.remove(feat_groups_dict[feat_groups[i]][j])
    # run logitstic regression with the best hyperparameter recursively 
    selector2 = SelectFromModel(estimator=LassoCV())
    
    preprocessor2 = ColumnTransformer(
                                 transformers=[
                                    ('num', numeric_transformer, num_feat_cur),
                                    ('cat', categorical_transformer, cat_feat_cur)
                                ])

    X_trans_sel_expr = selector2.fit_transform(preprocessor2.fit_transform(X), y)
    X_test_sel_expr = selector2.transform(preprocessor2.transform(X_test))
    
    lr_result_expr = cross_validate(lr_gridsearchCV, X_trans_sel_expr, y, cv=5,
                        scoring=('accuracy','f1','recall','precision','roc_auc'),
                        return_train_score=False)  
    lr_result_df_expr = format_cv_score(lr_result_expr)
    
    lr_decided = lr_gridsearchCV.best_estimator_.fit(X_trans_sel_expr, y)
    
    lr_test_result_expr = show_test_score(lr_decided, X_test_sel_expr, y_test)
    
    feat_expr_result[feat_groups[i]] = lr_result_df_expr
    feat_expr_test_result[feat_groups[i]] = lr_test_result_expr
    
    print("Current progress:", i+1, "/", len(feat_groups), np.round((i+1)/len(feat_groups)*100, 2), "%")
# Out:
# Current progress: 11 / 11 100.0 %

# %%
# cross_validation
columns = pd.MultiIndex.from_tuples(tuples, names=['', ''])
feat_index = ["all features"] + ["- " + s for s in list(feat_expr_result.keys()) ]
lr_df = pd.concat([lr_result_df, pd.concat(list(feat_expr_result.values()))])
lr_df.index = feat_index

lr_df2 = pd.concat([wc_lr_result_df, tfidf_lr_result_df, lr_df])
feat_index2 = ["Baseline 1: bag-of-word with lr", "Baseline 2: tf-idf with lr", "all features"] + \
["- " + s for s in list(feat_expr_result.keys()) ]
lr_df2.index = feat_index2
lr_df2.columns = columns

# %%
# test 
test_columns = pd.MultiIndex.from_tuples(test_tuples, names=['', ''])
feat_index = ["all features"] + ["- " + s for s in list(feat_expr_result.keys()) ]
lr_df_test = pd.concat([lr_test_df, pd.concat(list(feat_expr_test_result.values()))])
lr_df.index = feat_index

lr_df2_test = pd.concat([wc_lr_test_result, tfidf_lr_test_result, lr_df_test])
feat_index2 = ["Baseline 1: bag-of-word with lr", "Baseline 2: tf-idf with lr", "all features"] + \
["- " + s for s in list(feat_expr_result.keys()) ]
lr_df2_test.index = feat_index2
lr_df2_test.columns = test_columns

# %%
feat_expr_final_table_lr = pd.concat([lr_df2, lr_df2_test], axis=1)
feat_expr_final_table_lr
# Out:
#                                    cross-validation                           \
#                                            accuracy recall precision roc_auc
# Baseline 1: bag-of-word with lr               0.340  0.786     0.234   0.505
# Baseline 2: tf-idf with lr                    0.243  0.971     0.239   0.540
# all features                                  0.670  0.700     0.402   0.744
# - academic_background                         0.621  0.729     0.377   0.735
# - educational_level                           0.649  0.714     0.384   0.718
# - internal_glentel_profile                    0.670  0.700     0.402   0.744
# - job_counts                                  0.670  0.700     0.402   0.744
# - job_tenure_general                          0.688  0.700     0.424   0.729
# - job_tenure_industry                         0.670  0.700     0.402   0.744
# - knowledge_and_skills                        0.541  0.671     0.284   0.693
# ...

# %% [markdown]
# ### Use SVM with the best hyperparameter

# %%
# Experiment using SVM
from IPython.display import clear_output
feat_expr_result = dict()
feat_expr_test_result = dict()
for i in range(len(feat_groups)):
    clear_output(wait=True)
    cat_feat_cur = categorical.copy()
    num_feat_cur = numerical.copy()
    for j in range(len(feat_groups_dict[feat_groups[i]])):
        if feat_groups_dict[feat_groups[i]][j] in categorical:
            cat_feat_cur.remove(feat_groups_dict[feat_groups[i]][j])
        else:
            num_feat_cur.remove(feat_groups_dict[feat_groups[i]][j])
    # run logitstic regression with the best hyperparameter recursively 
    selector2 = SelectFromModel(estimator=LassoCV())
    
    preprocessor2 = ColumnTransformer(
                                 transformers=[
                                    ('num', numeric_transformer, num_feat_cur),
                                    ('cat', categorical_transformer, cat_feat_cur)
                                ])
    X_trans_sel_expr = selector2.fit_transform(preprocessor2.fit_transform(X), y)
    X_test_sel_expr = selector2.transform(preprocessor2.transform(X_test))
    
    svm_result_expr = cross_validate(svm_gridsearchCV, X_trans_sel_expr, y, cv=5,
                        scoring=('accuracy','f1','recall','precision','roc_auc'),
                        return_train_score=False)
    svm_result_df_expr = format_cv_score(svm_result_expr)
    
    svm_decided = svm_gridsearchCV.best_estimator_.fit(X_trans_sel_expr, y)
    svm_test_result_expr = show_test_score(svm_decided, X_test_sel_expr, y_test)
    
    feat_expr_result[feat_groups[i]] = svm_result_df_expr
    feat_expr_test_result[feat_groups[i]] = svm_test_result_expr
    
    print("Current progress:", i+1, "/", len(feat_groups), np.round((i+1)/len(feat_groups)*100, 2), "%")
# Out:
# Current progress: 11 / 11 100.0 %

# %%
# cross validation
feat_index = ["all features"] + ["- " + s for s in list(feat_expr_result.keys()) ]
svm_df = pd.concat([svm_result_df, pd.concat(list(feat_expr_result.values()))])
svm_df.index = feat_index

svm_df2 = pd.concat([wc_lr_result_df, tfidf_lr_result_df, svm_df])
feat_index2 = ["Baseline 1: bag-of-word with lr", "Baseline 2: tf-idf with lr", "all features"] + \
["- " + s for s in list(feat_expr_result.keys()) ]
svm_df2.index = feat_index2
svm_df2.columns = columns

# %%
# test 
test_columns = pd.MultiIndex.from_tuples(test_tuples, names=['', ''])
feat_index = ["all features"] + ["- " + s for s in list(feat_expr_result.keys()) ]
svm_df_test = pd.concat([svm_test_df, pd.concat(list(feat_expr_test_result.values()))])
svm_df.index = feat_index

svm_df2_test = pd.concat([wc_lr_test_result, tfidf_lr_test_result, svm_df_test])
feat_index2 = ["Baseline 1: bag-of-word with lr", "Baseline 2: tf-idf with lr", "all features"] + \
["- " + s for s in list(feat_expr_result.keys()) ]
svm_df2_test.index = feat_index2
svm_df2_test.columns = test_columns

# %%
feat_expr_final_table_svm = pd.concat([svm_df2, svm_df2_test], axis=1)
feat_expr_final_table_svm
# Out:
#                                    cross-validation                           \
#                                            accuracy recall precision roc_auc
# Baseline 1: bag-of-word with lr               0.340  0.786     0.234   0.505
# Baseline 2: tf-idf with lr                    0.243  0.971     0.239   0.540
# all features                                  0.698  0.643     0.434   0.708
# - academic_background                         0.639  0.771     0.392   0.727
# - educational_level                           0.629  0.729     0.369   0.704
# - internal_glentel_profile                    0.698  0.643     0.434   0.708
# - job_counts                                  0.698  0.643     0.434   0.708
# - job_tenure_general                          0.712  0.629     0.442   0.745
# - job_tenure_industry                         0.698  0.643     0.434   0.708
# - knowledge_and_skills                        0.535  0.643     0.261   0.650
# ...

# %% [markdown]
# ## Result
# After deciding selected features and the best classifiers, we are going to fit the best classifier to the entire training dataset and then use SHAP explainer to explain the model.
# - For now, the best classifier is __Logistic Regression__ becaues Logistic regression has higher scores

# %%
finalist = lr_gridsearchCV.best_estimator_.fit(X_trans_sel_lassocv, y)

# %% [markdown]
# ### ROC, Confusion matrix and weights

# %%
feat_names = X_sel_cols_lassocv
weights = finalist.coef_.flatten()
weights_finalist_df = show_weights(feat_names, weights, 7)
weights_finalist_df["Neg weights"] = weights_finalist_df["Neg weights"].apply(lambda x: x if x < 0 else "")
weights_finalist_df["Neg feats"] = weights_finalist_df["Neg feats"].apply(lambda x: "" if x in weights_finalist_df["Pos feats"].to_list() else x)
weights_finalist_df
# Out:
#                  Neg feats Neg weights                Pos feats  Pos weights
# 0       flag_hd_highschool   -0.233688    competitor_experience     0.323218
# 1  fitness_sports_jobtitle     -0.2004  sales_customer_base_exp     0.299537
# 2                                               trilingual_flag     0.251656
# 3                                         finance_concentration     0.190294
# 4                                               shortest_tenure     0.162897
# 5                                              cashier_jobtitle     0.157587
# 6                                          communication_skills     0.130803

# %%
disp = plot_confusion_matrix(finalist, X_test_trans_sel_lassocv, y_test,
                             display_labels=['Non-high performer', 'high performer'],
                             cmap=plt.cm.Blues, 
                             values_format = 'd')
disp.ax_.set_title('Confusion matrix for high performer validation data set')
# Out:
# Text(0.5, 1.0, 'Confusion matrix for high performer validation data set')

# %%
fpr, tpr, thresholds = roc_curve(y_test, finalist.predict_proba(X_test_trans_sel_lassocv)[:,1])

plt.plot(fpr, tpr);
plt.plot((0,1),(0,1),'--k');
plt.xlabel('false positive rate');
plt.ylabel('true positive rate');

# %% [markdown]
# ### Show probabilities for each observation in testing dataset

# %%
probs_df = show_probs(X_test.employee_code, y_test, finalist.predict(X_test_sel_lassocv), finalist.predict_proba(X_test_sel_lassocv), dataset="test")
probs_df
# Out:
#    employee_code  y_obs_test  y_pred_test  non-high performer  high performer  \
# 0            GKH         1.0          1.0            0.325072        0.674928
# 1            IP5         1.0          0.0            0.627073        0.372927
# 2            K3E         0.0          1.0            0.126398        0.873602
# 3            KQQ         0.0          0.0            0.875756        0.124244
# 4            KVU         0.0          1.0            0.458999        0.541001
# ..           ...         ...          ...                 ...             ...
# 67           NBQ         0.0          1.0            0.356965        0.643035
# 68           NCM         0.0          1.0            0.437332        0.562668
# 69           NCV         0.0          1.0            0.479965        0.520035
# 70           NDB         0.0          1.0            0.343739        0.656261
# 71           NDG         1.0          0.0            0.789807        0.210193
#
# ...

# %%
false_negative_test = probs_df[probs_df["False_negative"]==1]
false_negative_test
# Out:
#    employee_code  y_obs_test  y_pred_test  non-high performer  high performer  \
# 1            IP5         1.0          0.0            0.627073        0.372927
# 12           MRT         1.0          0.0            0.588301        0.411699
# 15           MVC         1.0          0.0            0.574925        0.425075
# 19           MVV         1.0          0.0            0.686201        0.313799
# 42           N4G         1.0          0.0            0.690810        0.309190
# 55           N72         1.0          0.0            0.793304        0.206696
# 71           NDG         1.0          0.0            0.789807        0.210193
#
#     False_positive  False_negative
# 1                0               1
# 12               0               1
# 15               0               1
# 19               0               1
# 42               0               1
# 55               0               1
# 71               0               1

# %% [markdown]
# ### SHAP explainer

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
# The SHAP values for training dataset 
explainer = shap.LinearExplainer(finalist, X_trans_sel_lassocv, feature_dependence="independent")
shap_values = explainer.shap_values(X_trans_sel_lassocv)
X_train_array = X_trans_sel_lassocv # we need to pass a dense version for the plotting functions

# %%
# The summary plot for training dataset  
shap.summary_plot(shap_values, X_train_array)

# %%
# The SHAP values for testing dataset 
explainer = shap.LinearExplainer(finalist, X_test_trans_sel_lassocv, feature_dependence="independent")
shap_values = explainer.shap_values(X_test_trans_sel_lassocv)
X_test_array = X_test_trans_sel_lassocv.to_numpy() # we need to pass a dense version for the plotting functions

# %%
# The summary plot for testing dataset 
shap.summary_plot(shap_values, X_test_array)

# %%
# Let's take a look at false negative case 
ind = false_negative_test.index[0]
shap.force_plot(
    explainer.expected_value, shap_values[ind,:], X_test_array[ind,:],
    feature_names=X_sel_cols_lassocv
)
# Out:
# <div id='iEJ6U2AJ4DH8RS4UBBWM8'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...
