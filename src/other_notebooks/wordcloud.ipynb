# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df = pd.read_csv('../../../Glentel Inc/HR Analytics - Documents/Capstone Data/ubc_mds_team_share/make_processed/manual_clean_training_dataset.csv')

# %%
clean_text = df['clean_text']

# %%
clean_text
# Out:
# 0      Avenue Tel reference available request objecti...
# 1      resume obtain utilize opportunity grow benefit...
# 2      Employment History Hill August present sale pr...
# 3      Manston Cres career OBJECTIVE seek time sale r...
# 4      resume Contact LinkedIn Skills Microsoft Offic...
#                              ...
# 283    Jess Road Saint work experience January Januar...
# 284    ARVI Thorncliffe Park CAREER OBJECTIVE work re...
# 285    PARAST LPH Yonge st Hill job objective gain pr...
# 286    Resume Sudury work experience Companionship Co...
# 287    Road objective obtain fulltime position grow o...
# Name: clean_text, Length: 288, dtype: object

# %%
for txt in clean_text:
    cloud_word = ''
    stopwords = set(STOPWORDS)
    txt = str(txt)
    tokens = txt.split()
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
      
    cloud_word += " ".join(tokens)+" " 
    
stopwords.update(["March"])

# %%
wordcloud = WordCloud(width = 800, height = 800,
                colormap='Blues',
                background_color ='black', 
                stopwords = stopwords,
                max_words= 500,
                min_font_size = 10).generate(cloud_word)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
wordcloud.to_file("../../img/resume_wordclo.png")
